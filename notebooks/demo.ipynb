# %%
# Add relevant Jupyter notebook extensions

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['/home/saenai/miniconda3/envs/B1/lib/python314.zip', '/home/saenai/miniconda3/envs/B1/lib/python3.14', '/home/saenai/miniconda3/envs/B1/lib/python3.14/lib-dynload', '', '/home/saenai/.local/lib/python3.14/site-packages', '/home/saenai/miniconda3/envs/B1/lib/python3.14/site-packages', '/home/saenai/project', '/home/saenai/project', '..', '..', '..', '..']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
import numpy as np
import sys
import os

# Simple way to add parent directory to path
sys.path.append('..')

from uuv_mission.dynamic import Submarine, Trajectory, ClosedLoop, Mission
from uuv_mission.control import Controller

# %%
# Reload the module to get the updated code
import importlib
import uuv_mission.dynamic
importlib.reload(uuv_mission.dynamic)
importlib.reload(uuv_mission.control)
from uuv_mission.dynamic import Submarine, Trajectory, ClosedLoop, Mission
from uuv_mission.control import Controller

# Create instances
sub = Submarine()
controller = Controller()  
closed_loop = ClosedLoop(sub, controller)

# Load mission from CSV (using the correct path)
mission = Mission.from_csv("../data/mission.csv")

print("About to run simulation...")
# Run simulation
trajectory = closed_loop.simulate_with_random_disturbances(mission)
print("Simulation completed!")

# This should work now without the recursion error
trajectory.plot_completed_mission(mission)
# Out:
# About to run simulation...
# Simulation completed!
